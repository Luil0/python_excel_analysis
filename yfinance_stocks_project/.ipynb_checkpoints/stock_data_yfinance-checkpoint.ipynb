# %%
import yfinance as yf 
import pandas as pd 
from datetime import datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt

# %%
class GetStockData:
    
    def __init__(self, tickers, start=datetime.today()-timedelta(days=365), end=datetime.today()):
        self.tickers = tickers
        self.stocks_data = yf.download(tickers, start, end)
        
    # gets the data for a specific stock that is in our stocks_data.
    def get_symbol(self, symbol):
        stocks_df = self.stocks_data.loc[:, self.stocks_data.columns.get_level_values(0).isin(["Date"]) | self.stocks_data.columns.get_level_values(1).isin([symbol])]
        return stocks_df
    
    # Get monthly data for a stock or the stocks that were in the ticker
    def monthly_data_ct(self, symbol=None):
        by_month = self.get_symbol(symbol).groupby(pd.Grouper(level="Date",freq="M"))
        full_data_by_month = self.stocks_data.groupby(pd.Grouper(level="Date", freq="M"))
        if symbol == None:
            ct = full_data_by_month
            
        else:
            ct = by_month
        
        # getting central tendency for our dataframe
        result = {"Mean":ct.mean(),
        "Max":ct.max(), "Min":ct.min()}
        result["Mean"].rename_axis("Month", inplace=True)
        result["Mean"].index = result["Mean"].index.strftime('%b-%Y')
        return result
        
        
        

tick = ["AAPL", "MSFT", "TSLA"]



df = GetStockData(tick).monthly_data_ct()["Mean"]

df.columns = [col[0]+" "+col[1] for col in df.columns]
df.rename(columns = {"Date":"Month"})
df.to_csv("stocks_monthly_mean_price.csv")
# df.rename_axis("Month")
# df.index = df.index.strftime("%B")
df
# Out:
# [*********************100%***********************]  3 of 3 completed
#           Adj Close AAPL  Adj Close MSFT  Adj Close TSLA  Close AAPL  \
# Month
# Apr-2022      162.909572      278.913753      321.379528  163.896428
# May-2022      147.708989      264.396266      255.223333  148.430477
# Jun-2022      139.160979      257.576537      234.025873  139.798573
# Jul-2022      148.987878      260.270873      251.394666  149.670499
# Aug-2022      166.315556      278.763721      294.869857  166.885218
# Sep-2022      152.516599      246.396725      288.734763  153.002856
# Oct-2022      144.552467      235.782346      223.810477  145.013333
# Nov-2022      145.586772      236.343528      191.246666  145.843331
# Dec-2022      137.666473      245.028654      152.970476  137.876666
# Jan-2023      135.572004      236.688166      134.195999  135.778999
# Feb-2023      150.883377      259.350614      199.775264  150.968421
# Mar-2023      154.964782      266.742610      188.522609  154.964782
# Apr-2023      165.055000      287.587502      189.482502  165.055000
#
#           Close MSFT  Close TSLA   High AAPL   High MSFT   High TSLA  \
# Month
# Apr-2022  281.649996  321.379528  167.137857  287.597855  334.299050
# May-2022  266.729046  255.223333  150.950952  270.596665  264.414288
# Jun-2022  259.499049  234.025873  141.919047  263.016667  241.544444
# Jul-2022  262.213496  251.394666  150.766000  264.817499  255.841666
# Aug-2022  280.564350  294.869857  168.589566  283.228258  301.852028
# Sep-2022  247.709999  288.734763  155.308573  251.147618  294.027140
# Oct-2022  237.039048  223.810477  146.800478  240.391905  229.788573
# Nov-2022  237.275237  191.246666  148.032855  240.118096  197.352381
# Dec-2022  245.642380  152.970476  140.166667  248.537619  158.921428
# Jan-2023  237.281000  134.195999  137.271498  239.668000  137.242999
